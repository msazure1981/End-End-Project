# %% [markdown]
# ![Install pandas-1.JPG](attachment:bcec93b1-2c6e-44f9-9b2d-aef8b93753fe.JPG)

# %% [markdown]
# ![Create db by pandas-2.JPG](attachment:78e239a1-8c5c-44d0-b69f-003b5c105eb1.JPG)

# %% [markdown]
# ![drop table etc-3.JPG](attachment:87ea30c4-8f96-455e-8ab5-3173a7c02973.JPG)

# %% [markdown]
# Read csv files and clean

# %% [markdown]
# ![read and manipulate columns-4.JPG](attachment:b981d754-45d6-4655-b31b-185c13e436ab.JPG)
